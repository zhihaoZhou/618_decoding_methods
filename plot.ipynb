# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
top_k_metrics = [(0.5038504665034143, 0.19414646464646462), (0.4861086572564422, 0.29412498229847345), (0.4717545282253694, 0.310766431796825), (0.45704400281288066, 0.3121880148425305), (0.4476006256627588, 0.3098661122760248), (0.43838007395308637, 0.3113310498891422), (0.4295332354550903, 0.3092088572522116), (0.42285221215938584, 0.30820474915652296), (0.4161912009449855, 0.30582119310739464), (0.41114016163350536, 0.30350790775029635)]

# %%
top_k_metrics
# Out:
# [(0.5038504665034143, 0.19414646464646462),
#  (0.4861086572564422, 0.29412498229847345),
#  (0.4717545282253694, 0.310766431796825),
#  (0.45704400281288066, 0.3121880148425305),
#  (0.4476006256627588, 0.3098661122760248),
#  (0.43838007395308637, 0.3113310498891422),
#  (0.4295332354550903, 0.3092088572522116),
#  (0.42285221215938584, 0.30820474915652296),
#  (0.4161912009449855, 0.30582119310739464),
#  (0.41114016163350536, 0.30350790775029635)]

# %%
x_top_k = [ele[0] for ele in top_k_metrics]
y_top_k = [ele[1] for ele in top_k_metrics]

# %%
nucleus_metrics = [(0.49746847966567226, 0.2278712651778689), (0.48637802929688556, 0.1853417273582131), (0.4891919227737064, 0.18945286413004378), (0.4848687241217916, 0.19556558898267437), (0.47830945493193816, 0.20813529501615946), (0.4691751561689957, 0.22382023591754727), (0.458627731871221, 0.24388428109657653), (0.44664396621641095, 0.26497876611202714), (0.43184968521999445, 0.2924079528799218)]

# %%
x_nucleus = [ele[0] for ele in nucleus_metrics]
y_nucleus = [ele[1] for ele in nucleus_metrics]

# %%
temp_metrics = [(0.27056298890531116, 0.8594871823271895), (0.2900273225698962, 0.7780941590368655), (0.314254329068444, 0.6939493891354637), (0.3345380792168378, 0.6186369533139898), (0.3534289866649694, 0.5520810181889031), (0.37208759438597155, 0.4904799899515876), (0.3879796899786916, 0.43740934015702954), (0.4013453897593912, 0.39205564008235977), (0.4125395531383838, 0.35336472200198815), (0.42107072377897686, 0.320970699035091)]

# %%
x_temp = [ele[0] for ele in temp_metrics]
y_temp = [ele[1] for ele in temp_metrics]

# %%
# plt.plot(x_top_k, y_top_k, '.r-')
plt.plot(x_nucleus, y_nucleus, '.b-')
# plt.plot(x_temp, y_temp, '.g-')
plt.show()
