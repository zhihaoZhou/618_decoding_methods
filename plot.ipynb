# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
top_k_metrics = [(0.5038504665034143, 0.19414646464646462), (0.4658780372806107, 0.544254148082519), (0.4370301122934975, 0.6392213460293618), (0.4115150779654563, 0.6955373082876686), (0.3917234758205553, 0.7075451264961937), (0.36373581273853517, 0.7522246739817057), (0.3536395506518063, 0.772113000316704), (0.3428227491628299, 0.7931165053617834), (0.3175053368387033, 0.8074383203710335), (0.2971022087514944, 0.8353640973631085), (0.29723292801764456, 0.8413316450168575)]

# %%
top_k_metrics
# Out:
# [(0.5038504665034143, 0.19414646464646462),
#  (0.4658780372806107, 0.544254148082519),
#  (0.4370301122934975, 0.6392213460293618),
#  (0.4115150779654563, 0.6955373082876686),
#  (0.3917234758205553, 0.7075451264961937),
#  (0.36373581273853517, 0.7522246739817057),
#  (0.3536395506518063, 0.772113000316704),
#  (0.3428227491628299, 0.7931165053617834),
#  (0.3175053368387033, 0.8074383203710335),
#  (0.2971022087514944, 0.8353640973631085),
#  (0.29723292801764456, 0.8413316450168575)]

# %%
x_top_k = [ele[0] for ele in top_k_metrics]
y_top_k = [ele[1] for ele in top_k_metrics]

# %%
nucleus_metrics = [(0.30447206507852564, 0.8205938835727099), (0.3529113082648603, 0.772750235477598), (0.41630752517796, 0.6951245335845431), (0.42301818337108515, 0.648938668094158), (0.45726635945208366, 0.5770275437453101), (0.4744582855286782, 0.5185280994553075), (0.4879587755400962, 0.43137562158278653), (0.4846282420574702, 0.3365353086131479), (0.49638332256089435, 0.2235695165940303)]

# %%
x_nucleus = [ele[0] for ele in nucleus_metrics]
y_nucleus = [ele[1] for ele in nucleus_metrics]

# %%
temp_metrics = [(0.27557134992517457, 0.8621883022921125), (0.3202063723018778, 0.8165583820724018), (0.3548837060936491, 0.7556044129392151), (0.40805037300179003, 0.7089961098023391), (0.4223432813910744, 0.647539047423508), (0.4524158471282892, 0.5869727235519592), (0.47792133610193455, 0.5191785278361806), (0.48808551540589384, 0.45632711576757734), (0.5070873382459192, 0.393052145361805), (0.49992800937092363, 0.2983588090113534)]

# %%
x_temp = [ele[0] for ele in temp_metrics]
y_temp = [ele[1] for ele in temp_metrics]

# %%
plt.plot(x_top_k, y_top_k, '.r-', label="top_k (k=1~100)")
plt.plot(x_nucleus, y_nucleus, '.b-', label="nucleus (P=0.1~0.9)")
plt.plot(x_temp, y_temp, '.g-', label="temperature (T=0.1~1)")
plt.legend(loc="lower left")
plt.xlabel('bleu-2', fontsize=10)
plt.ylabel('div-2', fontsize=10)
plt.show()
